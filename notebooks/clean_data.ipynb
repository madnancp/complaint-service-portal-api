# %%
import re
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/lynx/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/lynx/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/lynx/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/lynx/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package stopwords to /home/lynx/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df_path = "../data/raw/complaints.csv"
df = pd.read_csv(df_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5075 entries, 0 to 5074
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5075 non-null   int64
#  1   complaint   5075 non-null   object
#  2   category    5075 non-null   object
#  3   emotion     5075 non-null   object
#  4   department  5075 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 198.4+ KB

# %% [markdown]
# Remove Duplicates

# %%
df = df.drop(index=df[df[["complaint", "emotion", "category"]].duplicated()].index).reset_index().drop(columns=["index"])

# %%
df.head()
# Out:
#    Unnamed: 0                                          complaint category  \
# 0           0     A dog chased and attacked a child in our lane.   safety
# 1           1  A stray cattle blocked the road and caused an ...   safety
# 2           2  A stray dog attacked a child near beside the p...   safety
# 3           3  A stray dog attacked a child near beside the p...   safety
# 4           4  A stray dog attacked a child near beside the p...   safety
#
#    emotion    department
# 0    worry  Municipality
# 1    worry  Municipality
# 2    anger        Police
# 3  disgust        Police
# 4  disgust        Police

# %% [markdown]
# ## Remove Unwanted columns

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'complaint', 'category', 'emotion', 'department'], dtype='object')

# %%
df = df.drop(columns=["Unnamed: 0"])
df.head()
# Out:
#                                            complaint category  emotion  \
# 0     A dog chased and attacked a child in our lane.   safety    worry
# 1  A stray cattle blocked the road and caused an ...   safety    worry
# 2  A stray dog attacked a child near beside the p...   safety    anger
# 3  A stray dog attacked a child near beside the p...   safety  disgust
# 4  A stray dog attacked a child near beside the p...   safety  disgust
#
#      department
# 0  Municipality
# 1  Municipality
# 2        Police
# 3        Police
# 4        Police

# %% [markdown]
# #### Departments

# %%
df["department"].value_counts()
# Out:
# department
# Police               993
# Food Safety Dept.    961
# Municipality         931
# Health Dept.         931
# Sanitation Dept.     904
# Name: count, dtype: int64

# %% [markdown]
# #### Emotions

# %%
df["emotion"].value_counts()
# Out:
# emotion
# disgust        607
# concern        605
# anger          603
# worry          597
# neutral        589
# sadness        589
# urgency        568
# frustration    562
# Name: count, dtype: int64

# %% [markdown]
# #### Category

# %%
df["category"].value_counts()
# Out:
# category
# safety     998
# food       961
# illness    931
# water      926
# waste      904
# Name: count, dtype: int64

# %% [markdown]
# #### Text Preprocessing

# %% [markdown]
# Lowercasing & Remove extra spaces

# %%
df["complaint"].sample(10)
# Out:
# 542     Child developed rashes after drinking municipa...
# 1728    I suspect adulteration in the cooking oil used...
# 3979    Suspicious activities noticed near near the te...
# 263     Biscuit packet bought from milkman in near the...
# 2770    Pipeline leakage near in the municipal ward, M...
# 3180    Restaurant in near the temple, Mysuru served s...
# 3379    Sewage water overflowing onto the road in near...
# 1832    Kitchen waste attracting stray animals in behi...
# 4567    Vegetables in the near the market market of Vi...
# 2294    No water supply since morning in outside the s...
# Name: complaint, dtype: object

# %%
clean_fn = lambda x: re.sub(r'\s+', ' ', x).strip().lower()
df["complaint"] = df["complaint"].apply(clean_fn)

# %%
df["complaint"].sample(10)
# Out:
# 3772    students fell ill after eating from the fruit ...
# 4535    vegetables in the beside the park market of be...
# 3454    stagnant water near next to the metro station ...
# 3103    respiratory issues increasing due to pollution...
# 3327    sewage leak on the road in on the main road, c...
# 3555    stray dogs attacking pedestrians in opposite t...
# 382     borewell dried up; families in opposite the ho...
# 3404    sewage water overflowing onto the road in oppo...
# 1480    garbage truck skipped collection for a week in...
# 4515    uncollected kitchen waste is attracting stray ...
# Name: complaint, dtype: object

# %% [markdown]
# #### Remove punctuation

# %%
remove_punt = lambda x: re.sub(r'[^a-zA-Z\s]', '', x)
df["complaint"] = df["complaint"].apply(remove_punt)

# %%
df["complaint"].sample(5)
# Out:
# 3067    respiratory issues increasing due to pollution...
# 4423    trash burning openly in opposite the hospital ...
# 892     dumpyard near in the municipal ward releases f...
# 4003    tap water in at the bus stop of patna has been...
# 594     construction debris dumped illegally near in o...
# Name: complaint, dtype: object

# %% [markdown]
# #### Tokenizing

# %%
tokenize = lambda x: word_tokenize(x)

tokenized_complaints = df["complaint"].apply(tokenize).to_list()
tokenized_complaints
# Out:
# [['a', 'dog', 'chased', 'and', 'attacked', 'a', 'child', 'in', 'our', 'lane'],
#  ['a',
#   'stray',
#   'cattle',
#   'blocked',
#   'the',
#   'road',
#   'and',
#   'caused',
#   'an',
#   'accident'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'nagpur'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'nagpur'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'thiruvananthapuram'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'bhopal'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'bhopal'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'kolkata'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'mumbai'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'visakhapatnam'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'bhopal'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'mumbai'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'patna'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'trichy'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'trichy'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'kochi'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'lucknow'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'near',
#   'the',
#   'market',
#   'bengaluru'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'near',
#   'the',
#   'market',
#   'vellore'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'near',
#   'the',
#   'temple',
#   'trichy'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'on',
#   'the',
#   'main',
#   'road',
#   'kolkata'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'on',
#   'the',
#   'main',
#   'road',
#   'trichy'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'delhi'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'madurai'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'nagpur'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'patna'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'thiruvananthapuram'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'roaming',
#   'outside',
#   'our',
#   'apartment',
#   'at',
#   'midnight'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'pune'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'vellore'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'nagpur'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'chennai'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'bhopal'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'guwahati'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'chennai'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'trichy'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'patna'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'thiruvananthapuram'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'kolkata'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'madurai'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'patna'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'bengaluru'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'mumbai'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'pune'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'visakhapatnam'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'jaipur'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'kochi'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'pune'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'vellore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'visakhapatnam'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'bengaluru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'coimbatore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'guwahati'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'jaipur'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'pune'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'surat'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'thiruvananthapuram'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'visakhapatnam'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'mumbai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'mumbai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'nagpur'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'guwahati'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'madurai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'mangalore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'trichy'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'vellore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'bhopal'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'indore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'lucknow'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'mangalore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'mumbai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'pune'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'pune'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'thiruvananthapuram'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'visakhapatnam'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'bhopal'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'chennai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'mysuru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'pune'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'bengaluru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'delhi'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'jaipur'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'jaipur'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'kolkata'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'mumbai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'mysuru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'surat'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'market',
#   'mangalore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'market',
#   'mumbai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'market',
#   'mysuru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'bhopal'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'chennai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'hyderabad'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'hyderabad'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'indore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'mumbai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'mysuru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'vellore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'guwahati'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'hyderabad'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'mysuru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'nagpur'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'kochi'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'mangalore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'mysuru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'trichy'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'visakhapatnam'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'delhi'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'hyderabad'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'patna'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'surat'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'thiruvananthapuram'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'trichy'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'bhopal'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'coimbatore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'hyderabad'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'mysuru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'indore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'jaipur'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'nagpur'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'patna'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'trichy'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'bhopal'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'nagpur'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'delhi'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'delhi'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'lucknow'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'thiruvananthapuram'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'vellore'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'chennai'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'delhi'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'hyderabad'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'guwahati'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'visakhapatnam'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'near',
#   'the',
#   'market',
#   'bhopal'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'near',
#   'the',
#   'market',
#   'lucknow'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'near',
#   'the',
#   'market',
#   'nagpur'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'near',
#   'the',
#   'market',
#   'pune'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'near',
#   'the',
#   'market',
#   'visakhapatnam'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'on',
#   'the',
#   'main',
#   'road',
#   'vellore'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'delhi'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'mumbai'],
#  ['auto', 'drivers', 'are', 'refusing', 'rides', 'and', 'overcharging'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'in',
#   'kolkata'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'in',
#   'madurai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'in',
#   'mangalore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'in',
#   'thiruvananthapuram'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'in',
#   'vellore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'behind',
#   'the',
#   'apartment',
#   'in',
#   'guwahati'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'behind',
#   'the',
#   'apartment',
#   'in',
#   'jaipur'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'behind',
#   'the',
#   'apartment',
#   'in',
#   'jaipur'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'behind',
#   'the',
#   'apartment',
#   'in',
#   'lucknow'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'behind',
#   'the',
#   'apartment',
#   'in',
#   'mangalore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'behind',
#   'the',
#   'apartment',
#   'in',
#   'mumbai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'behind',
#   'the',
#   'apartment',
#   'in',
#   'thiruvananthapuram'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'behind',
#   'the',
#   'apartment',
#   'in',
#   'visakhapatnam'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'beside',
#   'the',
#   'park',
#   'in',
#   'coimbatore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'beside',
#   'the',
#   'park',
#   'in',
#   'guwahati'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'beside',
#   'the',
#   'park',
#   'in',
#   'jaipur'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'beside',
#   'the',
#   'park',
#   'in',
#   'kochi'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'beside',
#   'the',
#   'park',
#   'in',
#   'madurai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'beside',
#   'the',
#   'park',
#   'in',
#   'pune'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'beside',
#   'the',
#   'park',
#   'in',
#   'vellore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'by',
#   'the',
#   'lake',
#   'in',
#   'chennai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'by',
#   'the',
#   'lake',
#   'in',
#   'jaipur'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'by',
#   'the',
#   'lake',
#   'in',
#   'madurai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'by',
#   'the',
#   'lake',
#   'in',
#   'madurai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'by',
#   'the',
#   'lake',
#   'in',
#   'mysuru'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'by',
#   'the',
#   'lake',
#   'in',
#   'trichy'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'our',
#   'colony',
#   'in',
#   'delhi'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'our',
#   'colony',
#   'in',
#   'hyderabad'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'our',
#   'colony',
#   'in',
#   'mysuru'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'our',
#   'colony',
#   'in',
#   'pune'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'our',
#   'colony',
#   'in',
#   'surat'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'our',
#   'colony',
#   'in',
#   'trichy'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'in',
#   'bengaluru'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'in',
#   'jaipur'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'in',
#   'thiruvananthapuram'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'in',
#   'visakhapatnam'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'inside',
#   'the',
#   'hostel',
#   'in',
#   'indore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'inside',
#   'the',
#   'hostel',
#   'in',
#   'mumbai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'inside',
#   'the',
#   'hostel',
#   'in',
#   'mysuru'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'market',
#   'in',
#   'bhopal'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'market',
#   'in',
#   'coimbatore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'market',
#   'in',
#   'delhi'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'market',
#   'in',
#   'indore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'market',
#   'in',
#   'mangalore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'market',
#   'in',
#   'vellore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'in',
#   'delhi'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'in',
#   'hyderabad'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'in',
#   'vellore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'in',
#   'vellore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'temple',
#   'in',
#   'delhi'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'temple',
#   'in',
#   'kochi'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'temple',
#   'in',
#   'surat'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'temple',
#   'in',
#   'surat'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'temple',
#   'in',
#   'trichy'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'in',
#   'bengaluru'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'in',
#   'chennai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'in',
#   'guwahati'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'in',
#   'indore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'in',
#   'kochi'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'in',
#   'madurai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'on',
#   'the',
#   'main',
#   'road',
#   'in',
#   'hyderabad'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'on',
#   'the',
#   'main',
#   'road',
#   'in',
#   'indore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'on',
#   'the',
#   'main',
#   'road',
#   'in',
#   'surat'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'on',
#   'the',
#   'main',
#   'road',
#   'in',
#   'visakhapatnam'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'opposite',
#   'the',
#   'hospital',
#   'in',
#   'chennai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'opposite',
#   'the',
#   'hospital',
#   'in',
#   'jaipur'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'opposite',
#   'the',
#   'hospital',
#   'in',
#   'jaipur'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'opposite',
#   'the',
#   'hospital',
#   'in',
#   'madurai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'opposite',
#   'the',
#   'hospital',
#   'in',
#   'mangalore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'outside',
#   'the',
#   'school',
#   'in',
#   'bhopal'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'outside',
#   'the',
#   'school',
#   'in',
#   'coimbatore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'outside',
#   'the',
#   'school',
#   'in',
#   'guwahati'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'outside',
#   'the',
#   'school',
#   'in',
#   'lucknow'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'outside',
#   'the',
#   'school',
#   'in',
#   'patna'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'outside',
#   'the',
#   'school',
#   'in',
#   'pune'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'outside',
#   'the',
#   'school',
#   'in',
#   'pune'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'outside',
#   'the',
#   'school',
#   'in',
#   'trichy'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'bakery',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'thiruvananthapuram',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'bakery',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'chennai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'bakery',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'visakhapatnam',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'bakery',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'mangalore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'bakery',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'chennai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'bakery',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'bengaluru',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'bakery',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'coimbatore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'canteen',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'nagpur',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'canteen',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'madurai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'canteen',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'thiruvananthapuram',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'canteen',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'thiruvananthapuram',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'canteen',
#   'in',
#   'near',
#   'the',
#   'market',
#   'lucknow',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'canteen',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'madurai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'canteen',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'indore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'dhabha',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'kolkata',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'dhabha',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'patna',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'dhabha',
#   'in',
#   'near',
#   'the',
#   'market',
#   'madurai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'surat',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'kolkata',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'patna',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'trichy',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'bengaluru',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'bengaluru',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'mumbai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'thiruvananthapuram',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'jaipur',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'local',
#   'shop',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'hyderabad',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'local',
#   'shop',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'surat',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'local',
#   'shop',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'mumbai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'local',
#   'shop',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'kolkata',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'local',
#   'shop',
#   'in',
#   'near',
#   'the',
#   'market',
#   'surat',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'local',
#   'shop',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'patna',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'local',
#   'shop',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'chennai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'local',
#   'shop',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'vellore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'mess',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'visakhapatnam',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'mess',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'coimbatore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'mess',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'nagpur',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'mess',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'patna',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'mess',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'coimbatore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'milkman',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'chennai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'milkman',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'mangalore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'milkman',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'lucknow',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'milkman',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'pune',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'milkman',
#   'in',
#   'near',
#   'the',
#   'market',
#   'bhopal',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'milkman',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'visakhapatnam',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'ration',
#   'shop',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'trichy',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'ration',
#   'shop',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'delhi',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'ration',
#   'shop',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'mangalore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'ration',
#   'shop',
#   'in',
#   'near',
#   'the',
#   'market',
#   'kolkata',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'ration',
#   'shop',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'thiruvananthapuram',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'ration',
#   'shop',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'lucknow',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'restaurant',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'visakhapatnam',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'restaurant',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'delhi',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'restaurant',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'kolkata',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'restaurant',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'bhopal',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'restaurant',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'madurai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'restaurant',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'hyderabad',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'restaurant',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'mysuru',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'mangalore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'mangalore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'hyderabad',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'trichy',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'pune',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'trichy',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'mumbai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'bengaluru',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'chennai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'kochi',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'tea',
#   'stall',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'kochi',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'tea',
#   'stall',
#   'in',
#   'near',
#   'the',
#   'market',
#   'jaipur',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'tea',
#   'stall',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'hyderabad',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'tea',
#   'stall',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'jaipur',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'tea',
#   'stall',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'bhopal',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'vegetable',
#   'stall',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'thiruvananthapuram',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'vegetable',
#   'stall',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'jaipur',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'vegetable',
#   'stall',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'lucknow',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'vegetable',
#   'stall',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'coimbatore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'vegetable',
#   'stall',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'delhi',
#   'contained',
#   'insects'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'bengaluru',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'hyderabad',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'kolkata',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'lucknow',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'mumbai',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'vellore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'vellore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'bhopal',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'delhi',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'guwahati',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'guwahati',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'hyderabad',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'hyderabad',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'mangalore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'mumbai',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'thiruvananthapuram',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'bhopal',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'coimbatore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'kolkata',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'nagpur',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'bengaluru',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'chennai',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'indore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'pune',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'trichy',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'vellore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'visakhapatnam',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'bhopal',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'coimbatore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'indore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'jaipur',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'madurai',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'mangalore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'mangalore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'mumbai',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'nagpur',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'pune',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'pune',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'surat',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'vellore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'visakhapatnam',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'guwahati',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'kochi',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'mysuru',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'mysuru',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'trichy',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'visakhapatnam',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'bhopal',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'kochi',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'kochi',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'kolkata',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'patna',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'surat',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'thiruvananthapuram',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'bengaluru',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'guwahati',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'indore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'kochi',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'kochi',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'mangalore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'mangalore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'mumbai',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'vellore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'visakhapatnam',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'bengaluru',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'chennai',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'guwahati',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'visakhapatnam',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'coimbatore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'guwahati',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'madurai',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'trichy',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'vellore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'coimbatore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'mysuru',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'thiruvananthapuram',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'coimbatore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'mangalore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'thiruvananthapuram',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'trichy',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'vellore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'bhopal',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
# ...
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'hyderabad'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'jaipur'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'jaipur'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'kochi'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'kolkata'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'kolkata'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'kolkata'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'lucknow'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'madurai'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'madurai'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'mumbai'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'mumbai'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'nagpur'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'patna'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'patna'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'pune'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'pune'],
#  ['dumping', 'yard', 'smell', 'is', 'unbearable', 'at', 'night'],
#  ['dumpyard',
#   'near',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'behind',
#   'the',
#   'apartment',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'behind',
#   'the',
#   'apartment',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'behind',
#   'the',
#   'apartment',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'market',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'market',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'temple',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'temple',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'temple',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'temple',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'temple',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'on',
#   'the',
#   'main',
#   'road',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'on',
#   'the',
#   'main',
#   'road',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'on',
#   'the',
#   'main',
#   'road',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'on',
#   'the',
#   'main',
#   'road',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'opposite',
#   'the',
#   'hospital',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'bengaluru'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'bengaluru'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'bengaluru'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'bengaluru'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'bhopal'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'bhopal'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'bhopal'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'chennai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'chennai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'chennai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'chennai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'chennai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'coimbatore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'coimbatore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'coimbatore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'coimbatore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'coimbatore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'delhi'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'delhi'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'guwahati'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'guwahati'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'guwahati'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'hyderabad'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'hyderabad'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'hyderabad'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'indore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'indore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'indore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'indore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'jaipur'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'jaipur'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'jaipur'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'kochi'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'kochi'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'kolkata'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'kolkata'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'kolkata'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'kolkata'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'kolkata'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'lucknow'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'lucknow'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'lucknow'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'madurai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'madurai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'madurai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mangalore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mangalore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mangalore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mangalore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mangalore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mumbai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mumbai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mumbai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mysuru'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mysuru'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mysuru'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mysuru'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'nagpur'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'nagpur'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'nagpur'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'nagpur'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'patna'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'patna'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'pune'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'pune'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'surat'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'surat'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'thiruvananthapuram'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'thiruvananthapuram'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'thiruvananthapuram'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'thiruvananthapuram'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'thiruvananthapuram'],
#  ...]

# %% [markdown]
# #### Lemmatization

# %%
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
def preprocess(tokens):
    # POS tagging
    pos_tags = nltk.pos_tag(tokens)

    # lemmatize with POS
    lemmas = [
        lemmatizer.lemmatize(word, get_wordnet_pos(pos))
        for word, pos in pos_tags
    ]

    return " ".join(lemmas)

# %%
preprocess(tokenized_complaints[0])
# Out:
# 'a dog chase and attack a child in our lane'

# %%
tokenized_complaints[0]  # seems cool
# Out:
# ['a', 'dog', 'chased', 'and', 'attacked', 'a', 'child', 'in', 'our', 'lane']

# %%
tokenized_complaints
# Out:
# [['a', 'dog', 'chased', 'and', 'attacked', 'a', 'child', 'in', 'our', 'lane'],
#  ['a',
#   'stray',
#   'cattle',
#   'blocked',
#   'the',
#   'road',
#   'and',
#   'caused',
#   'an',
#   'accident'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'nagpur'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'nagpur'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'thiruvananthapuram'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'bhopal'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'bhopal'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'kolkata'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'mumbai'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'visakhapatnam'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'bhopal'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'mumbai'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'patna'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'trichy'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'trichy'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'kochi'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'lucknow'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'near',
#   'the',
#   'market',
#   'bengaluru'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'near',
#   'the',
#   'market',
#   'vellore'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'near',
#   'the',
#   'temple',
#   'trichy'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'on',
#   'the',
#   'main',
#   'road',
#   'kolkata'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'on',
#   'the',
#   'main',
#   'road',
#   'trichy'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'delhi'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'madurai'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'nagpur'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'patna'],
#  ['a',
#   'stray',
#   'dog',
#   'attacked',
#   'a',
#   'child',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'thiruvananthapuram'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'roaming',
#   'outside',
#   'our',
#   'apartment',
#   'at',
#   'midnight'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'pune'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'vellore'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'nagpur'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'chennai'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'bhopal'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'guwahati'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'chennai'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'trichy'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'patna'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'thiruvananthapuram'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'kolkata'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'madurai'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'patna'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'bengaluru'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'mumbai'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'pune'],
#  ['a',
#   'suspicious',
#   'person',
#   'was',
#   'seen',
#   'loitering',
#   'near',
#   'the',
#   'school',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'visakhapatnam'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'jaipur'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'kochi'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'pune'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'vellore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'visakhapatnam'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'bengaluru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'coimbatore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'guwahati'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'jaipur'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'pune'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'surat'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'thiruvananthapuram'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'visakhapatnam'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'mumbai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'mumbai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'nagpur'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'guwahati'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'madurai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'mangalore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'trichy'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'vellore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'bhopal'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'indore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'lucknow'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'mangalore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'mumbai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'pune'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'pune'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'thiruvananthapuram'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'visakhapatnam'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'bhopal'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'chennai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'mysuru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'pune'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'bengaluru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'delhi'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'jaipur'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'jaipur'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'kolkata'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'mumbai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'mysuru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'surat'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'market',
#   'mangalore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'market',
#   'mumbai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'market',
#   'mysuru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'bhopal'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'chennai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'hyderabad'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'hyderabad'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'indore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'mumbai'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'mysuru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'vellore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'guwahati'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'hyderabad'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'mysuru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'nagpur'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'kochi'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'mangalore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'mysuru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'trichy'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'visakhapatnam'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'delhi'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'hyderabad'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'patna'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'surat'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'thiruvananthapuram'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'trichy'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'bhopal'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'coimbatore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'hyderabad'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'mysuru'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'indore'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'jaipur'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'nagpur'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'patna'],
#  ['ambulance',
#   'delays',
#   'causing',
#   'panic',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'trichy'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'bhopal'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'nagpur'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'delhi'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'delhi'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'lucknow'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'thiruvananthapuram'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'vellore'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'chennai'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'delhi'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'hyderabad'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'guwahati'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'visakhapatnam'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'near',
#   'the',
#   'market',
#   'bhopal'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'near',
#   'the',
#   'market',
#   'lucknow'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'near',
#   'the',
#   'market',
#   'nagpur'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'near',
#   'the',
#   'market',
#   'pune'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'near',
#   'the',
#   'market',
#   'visakhapatnam'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'on',
#   'the',
#   'main',
#   'road',
#   'vellore'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'delhi'],
#  ['auto',
#   'drivers',
#   'are',
#   'overcharging',
#   'and',
#   'harassing',
#   'passengers',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'mumbai'],
#  ['auto', 'drivers', 'are', 'refusing', 'rides', 'and', 'overcharging'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'in',
#   'kolkata'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'in',
#   'madurai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'in',
#   'mangalore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'in',
#   'thiruvananthapuram'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'in',
#   'vellore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'behind',
#   'the',
#   'apartment',
#   'in',
#   'guwahati'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'behind',
#   'the',
#   'apartment',
#   'in',
#   'jaipur'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'behind',
#   'the',
#   'apartment',
#   'in',
#   'jaipur'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'behind',
#   'the',
#   'apartment',
#   'in',
#   'lucknow'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'behind',
#   'the',
#   'apartment',
#   'in',
#   'mangalore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'behind',
#   'the',
#   'apartment',
#   'in',
#   'mumbai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'behind',
#   'the',
#   'apartment',
#   'in',
#   'thiruvananthapuram'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'behind',
#   'the',
#   'apartment',
#   'in',
#   'visakhapatnam'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'beside',
#   'the',
#   'park',
#   'in',
#   'coimbatore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'beside',
#   'the',
#   'park',
#   'in',
#   'guwahati'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'beside',
#   'the',
#   'park',
#   'in',
#   'jaipur'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'beside',
#   'the',
#   'park',
#   'in',
#   'kochi'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'beside',
#   'the',
#   'park',
#   'in',
#   'madurai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'beside',
#   'the',
#   'park',
#   'in',
#   'pune'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'beside',
#   'the',
#   'park',
#   'in',
#   'vellore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'by',
#   'the',
#   'lake',
#   'in',
#   'chennai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'by',
#   'the',
#   'lake',
#   'in',
#   'jaipur'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'by',
#   'the',
#   'lake',
#   'in',
#   'madurai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'by',
#   'the',
#   'lake',
#   'in',
#   'madurai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'by',
#   'the',
#   'lake',
#   'in',
#   'mysuru'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'by',
#   'the',
#   'lake',
#   'in',
#   'trichy'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'our',
#   'colony',
#   'in',
#   'delhi'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'our',
#   'colony',
#   'in',
#   'hyderabad'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'our',
#   'colony',
#   'in',
#   'mysuru'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'our',
#   'colony',
#   'in',
#   'pune'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'our',
#   'colony',
#   'in',
#   'surat'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'our',
#   'colony',
#   'in',
#   'trichy'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'in',
#   'bengaluru'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'in',
#   'jaipur'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'in',
#   'thiruvananthapuram'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'in',
#   'visakhapatnam'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'inside',
#   'the',
#   'hostel',
#   'in',
#   'indore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'inside',
#   'the',
#   'hostel',
#   'in',
#   'mumbai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'inside',
#   'the',
#   'hostel',
#   'in',
#   'mysuru'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'market',
#   'in',
#   'bhopal'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'market',
#   'in',
#   'coimbatore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'market',
#   'in',
#   'delhi'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'market',
#   'in',
#   'indore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'market',
#   'in',
#   'mangalore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'market',
#   'in',
#   'vellore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'in',
#   'delhi'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'in',
#   'hyderabad'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'in',
#   'vellore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'in',
#   'vellore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'temple',
#   'in',
#   'delhi'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'temple',
#   'in',
#   'kochi'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'temple',
#   'in',
#   'surat'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'temple',
#   'in',
#   'surat'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'near',
#   'the',
#   'temple',
#   'in',
#   'trichy'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'in',
#   'bengaluru'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'in',
#   'chennai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'in',
#   'guwahati'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'in',
#   'indore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'in',
#   'kochi'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'in',
#   'madurai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'on',
#   'the',
#   'main',
#   'road',
#   'in',
#   'hyderabad'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'on',
#   'the',
#   'main',
#   'road',
#   'in',
#   'indore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'on',
#   'the',
#   'main',
#   'road',
#   'in',
#   'surat'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'on',
#   'the',
#   'main',
#   'road',
#   'in',
#   'visakhapatnam'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'opposite',
#   'the',
#   'hospital',
#   'in',
#   'chennai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'opposite',
#   'the',
#   'hospital',
#   'in',
#   'jaipur'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'opposite',
#   'the',
#   'hospital',
#   'in',
#   'jaipur'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'opposite',
#   'the',
#   'hospital',
#   'in',
#   'madurai'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'opposite',
#   'the',
#   'hospital',
#   'in',
#   'mangalore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'outside',
#   'the',
#   'school',
#   'in',
#   'bhopal'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'outside',
#   'the',
#   'school',
#   'in',
#   'coimbatore'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'outside',
#   'the',
#   'school',
#   'in',
#   'guwahati'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'outside',
#   'the',
#   'school',
#   'in',
#   'lucknow'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'outside',
#   'the',
#   'school',
#   'in',
#   'patna'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'outside',
#   'the',
#   'school',
#   'in',
#   'pune'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'outside',
#   'the',
#   'school',
#   'in',
#   'pune'],
#  ['auto',
#   'drivers',
#   'overcharging',
#   'at',
#   'outside',
#   'the',
#   'school',
#   'in',
#   'trichy'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'bakery',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'thiruvananthapuram',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'bakery',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'chennai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'bakery',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'visakhapatnam',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'bakery',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'mangalore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'bakery',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'chennai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'bakery',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'bengaluru',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'bakery',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'coimbatore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'canteen',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'nagpur',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'canteen',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'madurai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'canteen',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'thiruvananthapuram',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'canteen',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'thiruvananthapuram',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'canteen',
#   'in',
#   'near',
#   'the',
#   'market',
#   'lucknow',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'canteen',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'madurai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'canteen',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'indore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'dhabha',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'kolkata',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'dhabha',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'patna',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'dhabha',
#   'in',
#   'near',
#   'the',
#   'market',
#   'madurai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'surat',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'kolkata',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'patna',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'trichy',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'bengaluru',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'bengaluru',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'mumbai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'thiruvananthapuram',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'fruit',
#   'seller',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'jaipur',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'local',
#   'shop',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'hyderabad',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'local',
#   'shop',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'surat',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'local',
#   'shop',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'mumbai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'local',
#   'shop',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'kolkata',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'local',
#   'shop',
#   'in',
#   'near',
#   'the',
#   'market',
#   'surat',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'local',
#   'shop',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'patna',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'local',
#   'shop',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'chennai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'local',
#   'shop',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'vellore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'mess',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'visakhapatnam',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'mess',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'coimbatore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'mess',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'nagpur',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'mess',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'patna',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'mess',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'coimbatore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'milkman',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'chennai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'milkman',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'mangalore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'milkman',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'lucknow',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'milkman',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'pune',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'milkman',
#   'in',
#   'near',
#   'the',
#   'market',
#   'bhopal',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'milkman',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'visakhapatnam',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'ration',
#   'shop',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'trichy',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'ration',
#   'shop',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'delhi',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'ration',
#   'shop',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'mangalore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'ration',
#   'shop',
#   'in',
#   'near',
#   'the',
#   'market',
#   'kolkata',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'ration',
#   'shop',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'thiruvananthapuram',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'ration',
#   'shop',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'lucknow',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'restaurant',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'visakhapatnam',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'restaurant',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'delhi',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'restaurant',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'kolkata',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'restaurant',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'bhopal',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'restaurant',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'madurai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'restaurant',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'hyderabad',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'restaurant',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'mysuru',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'mangalore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'mangalore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'hyderabad',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'trichy',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'pune',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'trichy',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'mumbai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'bengaluru',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'chennai',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'street',
#   'vendor',
#   'in',
#   'outside',
#   'the',
#   'school',
#   'kochi',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'tea',
#   'stall',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'kochi',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'tea',
#   'stall',
#   'in',
#   'near',
#   'the',
#   'market',
#   'jaipur',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'tea',
#   'stall',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'hyderabad',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'tea',
#   'stall',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'jaipur',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'tea',
#   'stall',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'bhopal',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'vegetable',
#   'stall',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'thiruvananthapuram',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'vegetable',
#   'stall',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'jaipur',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'vegetable',
#   'stall',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'lucknow',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'vegetable',
#   'stall',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'coimbatore',
#   'contained',
#   'insects'],
#  ['biscuit',
#   'packet',
#   'bought',
#   'from',
#   'vegetable',
#   'stall',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'delhi',
#   'contained',
#   'insects'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'bengaluru',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'hyderabad',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'kolkata',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'lucknow',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'mumbai',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'vellore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'vellore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'bhopal',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'delhi',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'guwahati',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'guwahati',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'hyderabad',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'hyderabad',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'mangalore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'mumbai',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'behind',
#   'the',
#   'apartment',
#   'thiruvananthapuram',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'bhopal',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'coimbatore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'kolkata',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'beside',
#   'the',
#   'park',
#   'nagpur',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'bengaluru',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'chennai',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'indore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'pune',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'trichy',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'vellore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'by',
#   'the',
#   'lake',
#   'visakhapatnam',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'bhopal',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'coimbatore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'indore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'jaipur',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'madurai',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'mangalore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'mangalore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'mumbai',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'nagpur',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'pune',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'pune',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'surat',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'vellore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'our',
#   'colony',
#   'visakhapatnam',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'guwahati',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'kochi',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'mysuru',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'mysuru',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'trichy',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'visakhapatnam',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'bhopal',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'kochi',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'kochi',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'kolkata',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'patna',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'surat',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'inside',
#   'the',
#   'hostel',
#   'thiruvananthapuram',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'bengaluru',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'guwahati',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'indore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'kochi',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'kochi',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'mangalore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'mangalore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'mumbai',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'vellore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'market',
#   'visakhapatnam',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'bengaluru',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'chennai',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'guwahati',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'visakhapatnam',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'coimbatore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'guwahati',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'madurai',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'trichy',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'near',
#   'the',
#   'temple',
#   'vellore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'coimbatore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'mysuru',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'thiruvananthapuram',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'coimbatore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'mangalore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'thiruvananthapuram',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'trichy',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'on',
#   'the',
#   'main',
#   'road',
#   'vellore',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
#   'families',
#   'in',
#   'opposite',
#   'the',
#   'hospital',
#   'bhopal',
#   'are',
#   'struggling'],
#  ['borewell',
#   'dried',
#   'up',
# ...
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'hyderabad'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'jaipur'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'jaipur'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'kochi'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'kolkata'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'kolkata'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'kolkata'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'lucknow'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'madurai'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'madurai'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'mumbai'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'mumbai'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'nagpur'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'patna'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'patna'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'pune'],
#  ['dumping',
#   'yard',
#   'near',
#   'the',
#   'colony',
#   'emits',
#   'foul',
#   'smell',
#   'at',
#   'night',
#   'in',
#   'pune'],
#  ['dumping', 'yard', 'smell', 'is', 'unbearable', 'at', 'night'],
#  ['dumpyard',
#   'near',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'behind',
#   'the',
#   'apartment',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'behind',
#   'the',
#   'apartment',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'behind',
#   'the',
#   'apartment',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'beside',
#   'the',
#   'park',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'by',
#   'the',
#   'lake',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'our',
#   'colony',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'in',
#   'the',
#   'municipal',
#   'ward',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'inside',
#   'the',
#   'hostel',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'market',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'market',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'railway',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'temple',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'temple',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'temple',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'temple',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'near',
#   'the',
#   'temple',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'next',
#   'to',
#   'the',
#   'metro',
#   'station',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'on',
#   'the',
#   'main',
#   'road',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'on',
#   'the',
#   'main',
#   'road',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'on',
#   'the',
#   'main',
#   'road',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'on',
#   'the',
#   'main',
#   'road',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'opposite',
#   'the',
#   'hospital',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['dumpyard',
#   'near',
#   'outside',
#   'the',
#   'school',
#   'releases',
#   'foul',
#   'smell',
#   'daily'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'bengaluru'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'bengaluru'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'bengaluru'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'bengaluru'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'bhopal'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'bhopal'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'bhopal'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'chennai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'chennai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'chennai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'chennai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'chennai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'coimbatore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'coimbatore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'coimbatore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'coimbatore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'coimbatore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'delhi'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'delhi'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'guwahati'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'guwahati'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'guwahati'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'hyderabad'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'hyderabad'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'hyderabad'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'indore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'indore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'indore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'indore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'jaipur'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'jaipur'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'jaipur'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'kochi'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'kochi'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'kolkata'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'kolkata'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'kolkata'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'kolkata'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'kolkata'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'lucknow'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'lucknow'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'lucknow'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'madurai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'madurai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'madurai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mangalore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mangalore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mangalore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mangalore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mangalore'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mumbai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mumbai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mumbai'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mysuru'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mysuru'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mysuru'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'mysuru'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'nagpur'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'nagpur'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'nagpur'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'nagpur'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'patna'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'patna'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'pune'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'pune'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'surat'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'surat'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'thiruvananthapuram'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'thiruvananthapuram'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'thiruvananthapuram'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'thiruvananthapuram'],
#  ['essential',
#   'medicines',
#   'unavailable',
#   'at',
#   'hospital',
#   'pharmacy',
#   'in',
#   'thiruvananthapuram'],
#  ...]

# %%
list(map(preprocess, tokenized_complaints))
# Out:
# ['a dog chase and attack a child in our lane',
#  'a stray cattle block the road and cause an accident',
#  'a stray dog attack a child near beside the park nagpur',
#  'a stray dog attack a child near beside the park nagpur',
#  'a stray dog attack a child near beside the park thiruvananthapuram',
#  'a stray dog attack a child near by the lake bhopal',
#  'a stray dog attack a child near in our colony bhopal',
#  'a stray dog attack a child near in our colony kolkata',
#  'a stray dog attack a child near in our colony mumbai',
#  'a stray dog attack a child near in our colony visakhapatnam',
#  'a stray dog attack a child near in the municipal ward bhopal',
#  'a stray dog attack a child near in the municipal ward mumbai',
#  'a stray dog attack a child near in the municipal ward patna',
#  'a stray dog attack a child near in the municipal ward trichy',
#  'a stray dog attack a child near in the municipal ward trichy',
#  'a stray dog attack a child near inside the hostel kochi',
#  'a stray dog attack a child near inside the hostel lucknow',
#  'a stray dog attack a child near near the market bengaluru',
#  'a stray dog attack a child near near the market vellore',
#  'a stray dog attack a child near near the temple trichy',
#  'a stray dog attack a child near on the main road kolkata',
#  'a stray dog attack a child near on the main road trichy',
#  'a stray dog attack a child near outside the school delhi',
#  'a stray dog attack a child near outside the school madurai',
#  'a stray dog attack a child near outside the school nagpur',
#  'a stray dog attack a child near outside the school patna',
#  'a stray dog attack a child near outside the school thiruvananthapuram',
#  'a suspicious person be roam outside our apartment at midnight',
#  'a suspicious person be see loiter near the school in at the bus stop pune',
#  'a suspicious person be see loiter near the school in at the bus stop vellore',
#  'a suspicious person be see loiter near the school in beside the park nagpur',
#  'a suspicious person be see loiter near the school in by the lake chennai',
#  'a suspicious person be see loiter near the school in in our colony bhopal',
#  'a suspicious person be see loiter near the school in in our colony guwahati',
#  'a suspicious person be see loiter near the school in in the municipal ward chennai',
#  'a suspicious person be see loiter near the school in in the municipal ward trichy',
#  'a suspicious person be see loiter near the school in inside the hostel patna',
#  'a suspicious person be see loiter near the school in inside the hostel thiruvananthapuram',
#  'a suspicious person be see loiter near the school in near the temple kolkata',
#  'a suspicious person be see loiter near the school in near the temple madurai',
#  'a suspicious person be see loiter near the school in near the temple patna',
#  'a suspicious person be see loiter near the school in on the main road bengaluru',
#  'a suspicious person be see loiter near the school in on the main road mumbai',
#  'a suspicious person be see loiter near the school in outside the school pune',
#  'a suspicious person be see loiter near the school in outside the school visakhapatnam',
#  'ambulance delay cause panic in at the bus stop jaipur',
#  'ambulance delay cause panic in at the bus stop kochi',
#  'ambulance delay cause panic in at the bus stop pune',
#  'ambulance delay cause panic in at the bus stop vellore',
#  'ambulance delay cause panic in at the bus stop visakhapatnam',
#  'ambulance delay cause panic in behind the apartment bengaluru',
#  'ambulance delay cause panic in behind the apartment coimbatore',
#  'ambulance delay cause panic in behind the apartment guwahati',
#  'ambulance delay cause panic in behind the apartment jaipur',
#  'ambulance delay cause panic in behind the apartment pune',
#  'ambulance delay cause panic in behind the apartment surat',
#  'ambulance delay cause panic in behind the apartment thiruvananthapuram',
#  'ambulance delay cause panic in behind the apartment visakhapatnam',
#  'ambulance delay cause panic in beside the park mumbai',
#  'ambulance delay cause panic in beside the park mumbai',
#  'ambulance delay cause panic in beside the park nagpur',
#  'ambulance delay cause panic in by the lake guwahati',
#  'ambulance delay cause panic in by the lake madurai',
#  'ambulance delay cause panic in by the lake mangalore',
#  'ambulance delay cause panic in by the lake trichy',
#  'ambulance delay cause panic in by the lake vellore',
#  'ambulance delay cause panic in in our colony bhopal',
#  'ambulance delay cause panic in in our colony indore',
#  'ambulance delay cause panic in in our colony lucknow',
#  'ambulance delay cause panic in in our colony mangalore',
#  'ambulance delay cause panic in in our colony mumbai',
#  'ambulance delay cause panic in in our colony pune',
#  'ambulance delay cause panic in in our colony pune',
#  'ambulance delay cause panic in in our colony thiruvananthapuram',
#  'ambulance delay cause panic in in our colony visakhapatnam',
#  'ambulance delay cause panic in in the municipal ward bhopal',
#  'ambulance delay cause panic in in the municipal ward chennai',
#  'ambulance delay cause panic in in the municipal ward mysuru',
#  'ambulance delay cause panic in in the municipal ward pune',
#  'ambulance delay cause panic in inside the hostel bengaluru',
#  'ambulance delay cause panic in inside the hostel delhi',
#  'ambulance delay cause panic in inside the hostel jaipur',
#  'ambulance delay cause panic in inside the hostel jaipur',
#  'ambulance delay cause panic in inside the hostel kolkata',
#  'ambulance delay cause panic in inside the hostel mumbai',
#  'ambulance delay cause panic in inside the hostel mysuru',
#  'ambulance delay cause panic in inside the hostel surat',
#  'ambulance delay cause panic in near the market mangalore',
#  'ambulance delay cause panic in near the market mumbai',
#  'ambulance delay cause panic in near the market mysuru',
#  'ambulance delay cause panic in near the railway station bhopal',
#  'ambulance delay cause panic in near the railway station chennai',
#  'ambulance delay cause panic in near the railway station hyderabad',
#  'ambulance delay cause panic in near the railway station hyderabad',
#  'ambulance delay cause panic in near the railway station indore',
#  'ambulance delay cause panic in near the railway station mumbai',
#  'ambulance delay cause panic in near the railway station mysuru',
#  'ambulance delay cause panic in near the railway station vellore',
#  'ambulance delay cause panic in near the temple guwahati',
#  'ambulance delay cause panic in near the temple hyderabad',
#  'ambulance delay cause panic in near the temple mysuru',
#  'ambulance delay cause panic in near the temple nagpur',
#  'ambulance delay cause panic in next to the metro station kochi',
#  'ambulance delay cause panic in next to the metro station mangalore',
#  'ambulance delay cause panic in next to the metro station mysuru',
#  'ambulance delay cause panic in next to the metro station trichy',
#  'ambulance delay cause panic in next to the metro station visakhapatnam',
#  'ambulance delay cause panic in on the main road delhi',
#  'ambulance delay cause panic in on the main road hyderabad',
#  'ambulance delay cause panic in on the main road patna',
#  'ambulance delay cause panic in on the main road surat',
#  'ambulance delay cause panic in on the main road thiruvananthapuram',
#  'ambulance delay cause panic in on the main road trichy',
#  'ambulance delay cause panic in opposite the hospital bhopal',
#  'ambulance delay cause panic in opposite the hospital coimbatore',
#  'ambulance delay cause panic in opposite the hospital hyderabad',
#  'ambulance delay cause panic in opposite the hospital mysuru',
#  'ambulance delay cause panic in outside the school indore',
#  'ambulance delay cause panic in outside the school jaipur',
#  'ambulance delay cause panic in outside the school nagpur',
#  'ambulance delay cause panic in outside the school patna',
#  'ambulance delay cause panic in outside the school trichy',
#  'auto driver be overcharge and harass passenger near at the bus stop bhopal',
#  'auto driver be overcharge and harass passenger near at the bus stop nagpur',
#  'auto driver be overcharge and harass passenger near beside the park delhi',
#  'auto driver be overcharge and harass passenger near beside the park delhi',
#  'auto driver be overcharge and harass passenger near by the lake lucknow',
#  'auto driver be overcharge and harass passenger near by the lake thiruvananthapuram',
#  'auto driver be overcharge and harass passenger near by the lake vellore',
#  'auto driver be overcharge and harass passenger near in our colony chennai',
#  'auto driver be overcharge and harass passenger near in the municipal ward delhi',
#  'auto driver be overcharge and harass passenger near in the municipal ward hyderabad',
#  'auto driver be overcharge and harass passenger near inside the hostel guwahati',
#  'auto driver be overcharge and harass passenger near inside the hostel visakhapatnam',
#  'auto driver be overcharge and harass passenger near near the market bhopal',
#  'auto driver be overcharge and harass passenger near near the market lucknow',
#  'auto driver be overcharge and harass passenger near near the market nagpur',
#  'auto driver be overcharge and harass passenger near near the market pune',
#  'auto driver be overcharge and harass passenger near near the market visakhapatnam',
#  'auto driver be overcharge and harass passenger near on the main road vellore',
#  'auto driver be overcharge and harass passenger near outside the school delhi',
#  'auto driver be overcharge and harass passenger near outside the school mumbai',
#  'auto driver be refuse ride and overcharge',
#  'auto driver overcharge at at the bus stop in kolkata',
#  'auto driver overcharge at at the bus stop in madurai',
#  'auto driver overcharge at at the bus stop in mangalore',
#  'auto driver overcharge at at the bus stop in thiruvananthapuram',
#  'auto driver overcharge at at the bus stop in vellore',
#  'auto driver overcharge at behind the apartment in guwahati',
#  'auto driver overcharge at behind the apartment in jaipur',
#  'auto driver overcharge at behind the apartment in jaipur',
#  'auto driver overcharge at behind the apartment in lucknow',
#  'auto driver overcharge at behind the apartment in mangalore',
#  'auto driver overcharge at behind the apartment in mumbai',
#  'auto driver overcharge at behind the apartment in thiruvananthapuram',
#  'auto driver overcharge at behind the apartment in visakhapatnam',
#  'auto driver overcharge at beside the park in coimbatore',
#  'auto driver overcharge at beside the park in guwahati',
#  'auto driver overcharge at beside the park in jaipur',
#  'auto driver overcharge at beside the park in kochi',
#  'auto driver overcharge at beside the park in madurai',
#  'auto driver overcharge at beside the park in pune',
#  'auto driver overcharge at beside the park in vellore',
#  'auto driver overcharge at by the lake in chennai',
#  'auto driver overcharge at by the lake in jaipur',
#  'auto driver overcharge at by the lake in madurai',
#  'auto driver overcharge at by the lake in madurai',
#  'auto driver overcharge at by the lake in mysuru',
#  'auto driver overcharge at by the lake in trichy',
#  'auto driver overcharge at in our colony in delhi',
#  'auto driver overcharge at in our colony in hyderabad',
#  'auto driver overcharge at in our colony in mysuru',
#  'auto driver overcharge at in our colony in pune',
#  'auto driver overcharge at in our colony in surat',
#  'auto driver overcharge at in our colony in trichy',
#  'auto driver overcharge at in the municipal ward in bengaluru',
#  'auto driver overcharge at in the municipal ward in jaipur',
#  'auto driver overcharge at in the municipal ward in thiruvananthapuram',
#  'auto driver overcharge at in the municipal ward in visakhapatnam',
#  'auto driver overcharge at inside the hostel in indore',
#  'auto driver overcharge at inside the hostel in mumbai',
#  'auto driver overcharge at inside the hostel in mysuru',
#  'auto driver overcharge at near the market in bhopal',
#  'auto driver overcharge at near the market in coimbatore',
#  'auto driver overcharge at near the market in delhi',
#  'auto driver overcharge at near the market in indore',
#  'auto driver overcharge at near the market in mangalore',
#  'auto driver overcharge at near the market in vellore',
#  'auto driver overcharge at near the railway station in delhi',
#  'auto driver overcharge at near the railway station in hyderabad',
#  'auto driver overcharge at near the railway station in vellore',
#  'auto driver overcharge at near the railway station in vellore',
#  'auto driver overcharge at near the temple in delhi',
#  'auto driver overcharge at near the temple in kochi',
#  'auto driver overcharge at near the temple in surat',
#  'auto driver overcharge at near the temple in surat',
#  'auto driver overcharge at near the temple in trichy',
#  'auto driver overcharge at next to the metro station in bengaluru',
#  'auto driver overcharge at next to the metro station in chennai',
#  'auto driver overcharge at next to the metro station in guwahati',
#  'auto driver overcharge at next to the metro station in indore',
#  'auto driver overcharge at next to the metro station in kochi',
#  'auto driver overcharge at next to the metro station in madurai',
#  'auto driver overcharge at on the main road in hyderabad',
#  'auto driver overcharge at on the main road in indore',
#  'auto driver overcharge at on the main road in surat',
#  'auto driver overcharge at on the main road in visakhapatnam',
#  'auto driver overcharge at opposite the hospital in chennai',
#  'auto driver overcharge at opposite the hospital in jaipur',
#  'auto driver overcharge at opposite the hospital in jaipur',
#  'auto driver overcharge at opposite the hospital in madurai',
#  'auto driver overcharge at opposite the hospital in mangalore',
#  'auto driver overcharge at outside the school in bhopal',
#  'auto driver overcharge at outside the school in coimbatore',
#  'auto driver overcharge at outside the school in guwahati',
#  'auto driver overcharge at outside the school in lucknow',
#  'auto driver overcharge at outside the school in patna',
#  'auto driver overcharge at outside the school in pune',
#  'auto driver overcharge at outside the school in pune',
#  'auto driver overcharge at outside the school in trichy',
#  'biscuit packet buy from bakery in at the bus stop thiruvananthapuram contain insect',
#  'biscuit packet buy from bakery in behind the apartment chennai contain insect',
#  'biscuit packet buy from bakery in beside the park visakhapatnam contain insect',
#  'biscuit packet buy from bakery in inside the hostel mangalore contain insect',
#  'biscuit packet buy from bakery in near the temple chennai contain insect',
#  'biscuit packet buy from bakery in on the main road bengaluru contain insect',
#  'biscuit packet buy from bakery in on the main road coimbatore contain insect',
#  'biscuit packet buy from canteen in at the bus stop nagpur contain insect',
#  'biscuit packet buy from canteen in behind the apartment madurai contain insect',
#  'biscuit packet buy from canteen in behind the apartment thiruvananthapuram contain insect',
#  'biscuit packet buy from canteen in behind the apartment thiruvananthapuram contain insect',
#  'biscuit packet buy from canteen in near the market lucknow contain insect',
#  'biscuit packet buy from canteen in near the railway station madurai contain insect',
#  'biscuit packet buy from canteen in outside the school indore contain insect',
#  'biscuit packet buy from dhabha in beside the park kolkata contain insect',
#  'biscuit packet buy from dhabha in by the lake patna contain insect',
#  'biscuit packet buy from dhabha in near the market madurai contain insect',
#  'biscuit packet buy from fruit seller in in our colony surat contain insect',
#  'biscuit packet buy from fruit seller in inside the hostel kolkata contain insect',
#  'biscuit packet buy from fruit seller in inside the hostel patna contain insect',
#  'biscuit packet buy from fruit seller in inside the hostel trichy contain insect',
#  'biscuit packet buy from fruit seller in near the railway station bengaluru contain insect',
#  'biscuit packet buy from fruit seller in near the railway station bengaluru contain insect',
#  'biscuit packet buy from fruit seller in near the railway station mumbai contain insect',
#  'biscuit packet buy from fruit seller in opposite the hospital thiruvananthapuram contain insect',
#  'biscuit packet buy from fruit seller in outside the school jaipur contain insect',
#  'biscuit packet buy from local shop in at the bus stop hyderabad contain insect',
#  'biscuit packet buy from local shop in beside the park surat contain insect',
#  'biscuit packet buy from local shop in by the lake mumbai contain insect',
#  'biscuit packet buy from local shop in in our colony kolkata contain insect',
#  'biscuit packet buy from local shop in near the market surat contain insect',
#  'biscuit packet buy from local shop in opposite the hospital patna contain insect',
#  'biscuit packet buy from local shop in outside the school chennai contain insect',
#  'biscuit packet buy from local shop in outside the school vellore contain insect',
#  'biscuit packet buy from mess in at the bus stop visakhapatnam contain insect',
#  'biscuit packet buy from mess in in the municipal ward coimbatore contain insect',
#  'biscuit packet buy from mess in inside the hostel nagpur contain insect',
#  'biscuit packet buy from mess in inside the hostel patna contain insect',
#  'biscuit packet buy from mess in on the main road coimbatore contain insect',
#  'biscuit packet buy from milkman in at the bus stop chennai contain insect',
#  'biscuit packet buy from milkman in behind the apartment mangalore contain insect',
#  'biscuit packet buy from milkman in by the lake lucknow contain insect',
#  'biscuit packet buy from milkman in inside the hostel pune contain insect',
#  'biscuit packet buy from milkman in near the market bhopal contain insect',
#  'biscuit packet buy from milkman in next to the metro station visakhapatnam contain insect',
#  'biscuit packet buy from ration shop in at the bus stop trichy contain insect',
#  'biscuit packet buy from ration shop in in the municipal ward delhi contain insect',
#  'biscuit packet buy from ration shop in in the municipal ward mangalore contain insect',
#  'biscuit packet buy from ration shop in near the market kolkata contain insect',
#  'biscuit packet buy from ration shop in near the railway station thiruvananthapuram contain insect',
#  'biscuit packet buy from ration shop in next to the metro station lucknow contain insect',
#  'biscuit packet buy from restaurant in at the bus stop visakhapatnam contain insect',
#  'biscuit packet buy from restaurant in beside the park delhi contain insect',
#  'biscuit packet buy from restaurant in by the lake kolkata contain insect',
#  'biscuit packet buy from restaurant in in our colony bhopal contain insect',
#  'biscuit packet buy from restaurant in in our colony madurai contain insect',
#  'biscuit packet buy from restaurant in near the railway station hyderabad contain insect',
#  'biscuit packet buy from restaurant in on the main road mysuru contain insect',
#  'biscuit packet buy from street vendor in by the lake mangalore contain insect',
#  'biscuit packet buy from street vendor in in our colony mangalore contain insect',
#  'biscuit packet buy from street vendor in in the municipal ward hyderabad contain insect',
#  'biscuit packet buy from street vendor in in the municipal ward trichy contain insect',
#  'biscuit packet buy from street vendor in inside the hostel pune contain insect',
#  'biscuit packet buy from street vendor in near the railway station trichy contain insect',
#  'biscuit packet buy from street vendor in near the temple mumbai contain insect',
#  'biscuit packet buy from street vendor in opposite the hospital bengaluru contain insect',
#  'biscuit packet buy from street vendor in opposite the hospital chennai contain insect',
#  'biscuit packet buy from street vendor in outside the school kochi contain insect',
#  'biscuit packet buy from tea stall in inside the hostel kochi contain insect',
#  'biscuit packet buy from tea stall in near the market jaipur contain insect',
#  'biscuit packet buy from tea stall in near the railway station hyderabad contain insect',
#  'biscuit packet buy from tea stall in near the railway station jaipur contain insect',
#  'biscuit packet buy from tea stall in opposite the hospital bhopal contain insect',
#  'biscuit packet buy from vegetable stall in in our colony thiruvananthapuram contain insect',
#  'biscuit packet buy from vegetable stall in near the temple jaipur contain insect',
#  'biscuit packet buy from vegetable stall in near the temple lucknow contain insect',
#  'biscuit packet buy from vegetable stall in next to the metro station coimbatore contain insect',
#  'biscuit packet buy from vegetable stall in opposite the hospital delhi contain insect',
#  'borewell dry up family in at the bus stop bengaluru be struggle',
#  'borewell dry up family in at the bus stop hyderabad be struggle',
#  'borewell dry up family in at the bus stop kolkata be struggle',
#  'borewell dry up family in at the bus stop lucknow be struggle',
#  'borewell dry up family in at the bus stop mumbai be struggle',
#  'borewell dry up family in at the bus stop vellore be struggle',
#  'borewell dry up family in at the bus stop vellore be struggle',
#  'borewell dry up family in behind the apartment bhopal be struggle',
#  'borewell dry up family in behind the apartment delhi be struggle',
#  'borewell dry up family in behind the apartment guwahati be struggle',
#  'borewell dry up family in behind the apartment guwahati be struggle',
#  'borewell dry up family in behind the apartment hyderabad be struggle',
#  'borewell dry up family in behind the apartment hyderabad be struggle',
#  'borewell dry up family in behind the apartment mangalore be struggle',
#  'borewell dry up family in behind the apartment mumbai be struggle',
#  'borewell dry up family in behind the apartment thiruvananthapuram be struggle',
#  'borewell dry up family in beside the park bhopal be struggle',
#  'borewell dry up family in beside the park coimbatore be struggle',
#  'borewell dry up family in beside the park kolkata be struggle',
#  'borewell dry up family in beside the park nagpur be struggle',
#  'borewell dry up family in by the lake bengaluru be struggle',
#  'borewell dry up family in by the lake chennai be struggle',
#  'borewell dry up family in by the lake indore be struggle',
#  'borewell dry up family in by the lake pune be struggle',
#  'borewell dry up family in by the lake trichy be struggle',
#  'borewell dry up family in by the lake vellore be struggle',
#  'borewell dry up family in by the lake visakhapatnam be struggle',
#  'borewell dry up family in in our colony bhopal be struggle',
#  'borewell dry up family in in our colony coimbatore be struggle',
#  'borewell dry up family in in our colony indore be struggle',
#  'borewell dry up family in in our colony jaipur be struggle',
#  'borewell dry up family in in our colony madurai be struggle',
#  'borewell dry up family in in our colony mangalore be struggle',
#  'borewell dry up family in in our colony mangalore be struggle',
#  'borewell dry up family in in our colony mumbai be struggle',
#  'borewell dry up family in in our colony nagpur be struggle',
#  'borewell dry up family in in our colony pune be struggle',
#  'borewell dry up family in in our colony pune be struggle',
#  'borewell dry up family in in our colony surat be struggle',
#  'borewell dry up family in in our colony vellore be struggle',
#  'borewell dry up family in in our colony visakhapatnam be struggle',
#  'borewell dry up family in in the municipal ward guwahati be struggle',
#  'borewell dry up family in in the municipal ward kochi be struggle',
#  'borewell dry up family in in the municipal ward mysuru be struggle',
#  'borewell dry up family in in the municipal ward mysuru be struggle',
#  'borewell dry up family in in the municipal ward trichy be struggle',
#  'borewell dry up family in in the municipal ward visakhapatnam be struggle',
#  'borewell dry up family in inside the hostel bhopal be struggle',
#  'borewell dry up family in inside the hostel kochi be struggle',
#  'borewell dry up family in inside the hostel kochi be struggle',
#  'borewell dry up family in inside the hostel kolkata be struggle',
#  'borewell dry up family in inside the hostel patna be struggle',
#  'borewell dry up family in inside the hostel surat be struggle',
#  'borewell dry up family in inside the hostel thiruvananthapuram be struggle',
#  'borewell dry up family in near the market bengaluru be struggle',
#  'borewell dry up family in near the market guwahati be struggle',
#  'borewell dry up family in near the market indore be struggle',
#  'borewell dry up family in near the market kochi be struggle',
#  'borewell dry up family in near the market kochi be struggle',
#  'borewell dry up family in near the market mangalore be struggle',
#  'borewell dry up family in near the market mangalore be struggle',
#  'borewell dry up family in near the market mumbai be struggle',
#  'borewell dry up family in near the market vellore be struggle',
#  'borewell dry up family in near the market visakhapatnam be struggle',
#  'borewell dry up family in near the railway station bengaluru be struggle',
#  'borewell dry up family in near the railway station chennai be struggle',
#  'borewell dry up family in near the railway station guwahati be struggle',
#  'borewell dry up family in near the railway station visakhapatnam be struggle',
#  'borewell dry up family in near the temple coimbatore be struggle',
#  'borewell dry up family in near the temple guwahati be struggle',
#  'borewell dry up family in near the temple madurai be struggle',
#  'borewell dry up family in near the temple trichy be struggle',
#  'borewell dry up family in near the temple vellore be struggle',
#  'borewell dry up family in next to the metro station coimbatore be struggle',
#  'borewell dry up family in next to the metro station mysuru be struggle',
#  'borewell dry up family in next to the metro station thiruvananthapuram be struggle',
#  'borewell dry up family in on the main road coimbatore be struggle',
#  'borewell dry up family in on the main road mangalore be struggle',
#  'borewell dry up family in on the main road thiruvananthapuram be struggle',
#  'borewell dry up family in on the main road trichy be struggle',
#  'borewell dry up family in on the main road vellore be struggle',
#  'borewell dry up family in opposite the hospital bhopal be struggle',
#  'borewell dry up family in opposite the hospital coimbatore be struggle',
#  'borewell dry up family in opposite the hospital hyderabad be struggle',
#  'borewell dry up family in opposite the hospital madurai be struggle',
#  'borewell dry up family in opposite the hospital madurai be struggle',
#  'borewell dry up family in opposite the hospital mangalore be struggle',
#  'borewell dry up family in opposite the hospital mumbai be struggle',
#  'borewell dry up family in opposite the hospital pune be struggle',
#  'borewell dry up family in outside the school mangalore be struggle',
#  'borewell dry up family in outside the school mumbai be struggle',
#  'borewell dry up family in outside the school mumbai be struggle',
#  'borewell dry up family in outside the school patna be struggle',
#  'borewell dry up family in outside the school surat be struggle',
#  'borewell dry up family in outside the school surat be struggle',
#  'borewell dry up family in outside the school thiruvananthapuram be struggle',
#  'borewell dry up family in outside the school visakhapatnam be struggle',
#  'borewell have run dry villager in at the bus stop bengaluru need a new source',
#  'borewell have run dry villager in at the bus stop bengaluru need a new source',
#  'borewell have run dry villager in at the bus stop vellore need a new source',
#  'borewell have run dry villager in by the lake bhopal need a new source',
#  'borewell have run dry villager in in our colony kochi need a new source',
#  'borewell have run dry villager in in our colony pune need a new source',
#  'borewell have run dry villager in in the municipal ward visakhapatnam need a new source',
#  'borewell have run dry villager in inside the hostel hyderabad need a new source',
#  'borewell have run dry villager in inside the hostel kolkata need a new source',
#  'borewell have run dry villager in near the market thiruvananthapuram need a new source',
#  'borewell have run dry villager in near the temple pune need a new source',
#  'borewell have run dry villager in on the main road bhopal need a new source',
#  'borewell have run dry villager in on the main road hyderabad need a new source',
#  'borewell have run dry villager in on the main road lucknow need a new source',
#  'borewell have run dry villager in on the main road patna need a new source',
#  'borewell have run dry villager in on the main road thiruvananthapuram need a new source',
#  'borewell have run dry villager in on the main road vellore need a new source',
#  'borewell have run dry villager in on the main road visakhapatnam need a new source',
#  'borewell have run dry villager in outside the school bhopal need a new source',
#  'borewell have run dry villager in outside the school pune need a new source',
#  'busy junction at at the bus stop coimbatore lack pedestrian crossing',
#  'busy junction at at the bus stop lucknow lack pedestrian crossing',
#  'busy junction at at the bus stop mangalore lack pedestrian crossing',
#  'busy junction at at the bus stop surat lack pedestrian crossing',
#  'busy junction at behind the apartment bhopal lack pedestrian crossing',
#  'busy junction at behind the apartment coimbatore lack pedestrian crossing',
#  'busy junction at behind the apartment jaipur lack pedestrian crossing',
#  'busy junction at behind the apartment pune lack pedestrian crossing',
#  'busy junction at behind the apartment surat lack pedestrian crossing',
#  'busy junction at behind the apartment thiruvananthapuram lack pedestrian crossing',
#  'busy junction at beside the park bengaluru lack pedestrian crossing',
#  'busy junction at beside the park hyderabad lack pedestrian crossing',
#  'busy junction at beside the park lucknow lack pedestrian crossing',
#  'busy junction at beside the park mysuru lack pedestrian crossing',
#  'busy junction at beside the park pune lack pedestrian crossing',
#  'busy junction at beside the park trichy lack pedestrian crossing',
#  'busy junction at beside the park vellore lack pedestrian crossing',
#  'busy junction at by the lake coimbatore lack pedestrian crossing',
#  'busy junction at by the lake coimbatore lack pedestrian crossing',
#  'busy junction at by the lake indore lack pedestrian crossing',
#  'busy junction at by the lake surat lack pedestrian crossing',
#  'busy junction at by the lake thiruvananthapuram lack pedestrian crossing',
#  'busy junction at by the lake trichy lack pedestrian crossing',
#  'busy junction at by the lake vellore lack pedestrian crossing',
#  'busy junction at by the lake visakhapatnam lack pedestrian crossing',
#  'busy junction at in our colony indore lack pedestrian crossing',
#  'busy junction at in our colony mumbai lack pedestrian crossing',
#  'busy junction at in our colony surat lack pedestrian crossing',
#  'busy junction at in our colony vellore lack pedestrian crossing',
#  'busy junction at in the municipal ward bhopal lack pedestrian crossing',
#  'busy junction at in the municipal ward chennai lack pedestrian crossing',
#  'busy junction at in the municipal ward chennai lack pedestrian crossing',
#  'busy junction at in the municipal ward mysuru lack pedestrian crossing',
#  'busy junction at in the municipal ward nagpur lack pedestrian crossing',
#  'busy junction at in the municipal ward patna lack pedestrian crossing',
#  'busy junction at inside the hostel bengaluru lack pedestrian crossing',
#  'busy junction at inside the hostel coimbatore lack pedestrian crossing',
#  'busy junction at inside the hostel hyderabad lack pedestrian crossing',
#  'busy junction at inside the hostel mysuru lack pedestrian crossing',
#  'busy junction at near the market jaipur lack pedestrian crossing',
#  'busy junction at near the market jaipur lack pedestrian crossing',
#  'busy junction at near the market madurai lack pedestrian crossing',
#  'busy junction at near the market patna lack pedestrian crossing',
#  'busy junction at near the railway station chennai lack pedestrian crossing',
#  'busy junction at near the railway station pune lack pedestrian crossing',
#  'busy junction at near the temple bhopal lack pedestrian crossing',
#  'busy junction at near the temple hyderabad lack pedestrian crossing',
#  'busy junction at near the temple kochi lack pedestrian crossing',
#  'busy junction at near the temple kolkata lack pedestrian crossing',
#  'busy junction at near the temple vellore lack pedestrian crossing',
#  'busy junction at near the temple visakhapatnam lack pedestrian crossing',
#  'busy junction at next to the metro station bengaluru lack pedestrian crossing',
#  'busy junction at next to the metro station bhopal lack pedestrian crossing',
#  'busy junction at next to the metro station guwahati lack pedestrian crossing',
#  'busy junction at next to the metro station jaipur lack pedestrian crossing',
#  'busy junction at next to the metro station mumbai lack pedestrian crossing',
#  'busy junction at next to the metro station patna lack pedestrian crossing',
#  'busy junction at next to the metro station surat lack pedestrian crossing',
#  'busy junction at next to the metro station vellore lack pedestrian crossing',
#  'busy junction at on the main road kolkata lack pedestrian crossing',
#  'busy junction at on the main road kolkata lack pedestrian crossing',
#  'busy junction at on the main road lucknow lack pedestrian crossing',
#  'busy junction at on the main road mysuru lack pedestrian crossing',
#  'busy junction at on the main road surat lack pedestrian crossing',
#  'busy junction at opposite the hospital chennai lack pedestrian crossing',
#  'busy junction at opposite the hospital mumbai lack pedestrian crossing',
#  'busy junction at opposite the hospital patna lack pedestrian crossing',
#  'busy junction at opposite the hospital thiruvananthapuram lack pedestrian crossing',
#  'busy junction at outside the school bhopal lack pedestrian crossing',
#  'busy junction at outside the school delhi lack pedestrian crossing',
#  'busy junction at outside the school kolkata lack pedestrian crossing',
#  'busy junction at outside the school mangalore lack pedestrian crossing',
#  'busy junction at outside the school patna lack pedestrian crossing',
#  'busy junction at outside the school surat lack pedestrian crossing',
#  'busy junction at outside the school trichy lack pedestrian crossing',
#  'child develop rash after drink municipal water in at the bus stop',
#  'child develop rash after drink municipal water in at the bus stop',
#  'child develop rash after drink municipal water in at the bus stop',
#  'child develop rash after drink municipal water in at the bus stop',
#  'child develop rash after drink municipal water in behind the apartment',
#  'child develop rash after drink municipal water in behind the apartment',
#  'child develop rash after drink municipal water in behind the apartment',
#  'child develop rash after drink municipal water in behind the apartment',
#  'child develop rash after drink municipal water in behind the apartment',
#  'child develop rash after drink municipal water in behind the apartment',
#  'child develop rash after drink municipal water in beside the park',
#  'child develop rash after drink municipal water in beside the park',
#  'child develop rash after drink municipal water in beside the park',
#  'child develop rash after drink municipal water in beside the park',
#  'child develop rash after drink municipal water in beside the park',
#  'child develop rash after drink municipal water in by the lake',
#  'child develop rash after drink municipal water in by the lake',
#  'child develop rash after drink municipal water in by the lake',
#  'child develop rash after drink municipal water in by the lake',
#  'child develop rash after drink municipal water in in our colony',
#  'child develop rash after drink municipal water in in our colony',
#  'child develop rash after drink municipal water in in our colony',
#  'child develop rash after drink municipal water in in the municipal ward',
#  'child develop rash after drink municipal water in in the municipal ward',
#  'child develop rash after drink municipal water in inside the hostel',
#  'child develop rash after drink municipal water in inside the hostel',
#  'child develop rash after drink municipal water in inside the hostel',
#  'child develop rash after drink municipal water in near the market',
#  'child develop rash after drink municipal water in near the market',
#  'child develop rash after drink municipal water in near the market',
#  'child develop rash after drink municipal water in near the market',
#  'child develop rash after drink municipal water in near the market',
#  'child develop rash after drink municipal water in near the market',
#  'child develop rash after drink municipal water in near the railway station',
#  'child develop rash after drink municipal water in near the railway station',
#  'child develop rash after drink municipal water in near the railway station',
#  'child develop rash after drink municipal water in near the railway station',
#  'child develop rash after drink municipal water in near the temple',
#  'child develop rash after drink municipal water in near the temple',
#  'child develop rash after drink municipal water in near the temple',
#  'child develop rash after drink municipal water in near the temple',
#  'child develop rash after drink municipal water in near the temple',
#  'child develop rash after drink municipal water in next to the metro station',
#  'child develop rash after drink municipal water in next to the metro station',
#  'child develop rash after drink municipal water in next to the metro station',
#  'child develop rash after drink municipal water in on the main road',
#  'child develop rash after drink municipal water in on the main road',
#  'child develop rash after drink municipal water in opposite the hospital',
#  'child develop rash after drink municipal water in opposite the hospital',
#  'child develop rash after drink municipal water in opposite the hospital',
#  'child develop rash after drink municipal water in opposite the hospital',
#  'child develop rash after drink municipal water in opposite the hospital',
#  'child develop rash after drink municipal water in outside the school',
#  'child develop rash after drink municipal water in outside the school',
#  'child fell sick due to dirty surroundings near the house',
#  'child vomit continuously after eat hostel food',
#  'child fell sick after eat midday meal at school in bengaluru',
#  'child fell sick after eat midday meal at school in bengaluru',
#  'child fell sick after eat midday meal at school in bhopal',
#  'child fell sick after eat midday meal at school in guwahati',
#  'child fell sick after eat midday meal at school in kochi',
#  'child fell sick after eat midday meal at school in kochi',
#  'child fell sick after eat midday meal at school in kochi',
#  'child fell sick after eat midday meal at school in lucknow',
#  'child fell sick after eat midday meal at school in lucknow',
#  'child fell sick after eat midday meal at school in mumbai',
#  'child fell sick after eat midday meal at school in patna',
#  'child fell sick after eat midday meal at school in patna',
#  'child fell sick after eat midday meal at school in thiruvananthapuram',
#  'child fell sick after eat midday meal at school in thiruvananthapuram',
#  'child fell sick after eat midday meal at school in trichy',
#  'child fell sick after eat midday meal at school in vellore',
#  'child fell sick after eat midday meal at school in vellore',
#  'child fell sick after eat midday meal at school in visakhapatnam',
#  'child fell sick after eat midday meal at school in visakhapatnam',
#  'clinic staff at the government hospital be rude and unhelpful in bengaluru',
#  'clinic staff at the government hospital be rude and unhelpful in bengaluru',
#  'clinic staff at the government hospital be rude and unhelpful in coimbatore',
#  'clinic staff at the government hospital be rude and unhelpful in delhi',
#  'clinic staff at the government hospital be rude and unhelpful in hyderabad',
#  'clinic staff at the government hospital be rude and unhelpful in jaipur',
#  'clinic staff at the government hospital be rude and unhelpful in lucknow',
#  'clinic staff at the government hospital be rude and unhelpful in madurai',
#  'clinic staff at the government hospital be rude and unhelpful in madurai',
#  'clinic staff at the government hospital be rude and unhelpful in mumbai',
#  'clinic staff at the government hospital be rude and unhelpful in mumbai',
#  'clinic staff at the government hospital be rude and unhelpful in pune',
#  'clinic staff at the government hospital be rude and unhelpful in trichy',
#  'construction debris dump illegally near at the bus stop obstruct road',
#  'construction debris dump illegally near at the bus stop obstruct road',
#  'construction debris dump illegally near at the bus stop obstruct road',
#  'construction debris dump illegally near at the bus stop obstruct road',
#  'construction debris dump illegally near behind the apartment obstruct road',
#  'construction debris dump illegally near behind the apartment obstruct road',
#  'construction debris dump illegally near behind the apartment obstruct road',
#  'construction debris dump illegally near behind the apartment obstruct road',
#  'construction debris dump illegally near beside the park obstruct road',
#  'construction debris dump illegally near beside the park obstruct road',
#  'construction debris dump illegally near beside the park obstruct road',
#  'construction debris dump illegally near beside the park obstruct road',
#  'construction debris dump illegally near by the lake obstruct road',
#  'construction debris dump illegally near by the lake obstruct road',
#  'construction debris dump illegally near in our colony obstruct road',
#  'construction debris dump illegally near in our colony obstruct road',
#  'construction debris dump illegally near in our colony obstruct road',
#  'construction debris dump illegally near in our colony obstruct road',
#  'construction debris dump illegally near in the municipal ward obstruct road',
#  'construction debris dump illegally near in the municipal ward obstruct road',
#  'construction debris dump illegally near in the municipal ward obstruct road',
#  'construction debris dump illegally near in the municipal ward obstruct road',
#  'construction debris dump illegally near in the municipal ward obstruct road',
#  'construction debris dump illegally near in the municipal ward obstruct road',
#  'construction debris dump illegally near in the municipal ward obstruct road',
#  'construction debris dump illegally near inside the hostel obstruct road',
#  'construction debris dump illegally near inside the hostel obstruct road',
#  'construction debris dump illegally near inside the hostel obstruct road',
#  'construction debris dump illegally near inside the hostel obstruct road',
#  'construction debris dump illegally near inside the hostel obstruct road',
#  'construction debris dump illegally near inside the hostel obstruct road',
#  'construction debris dump illegally near near the market obstruct road',
#  'construction debris dump illegally near near the market obstruct road',
#  'construction debris dump illegally near near the market obstruct road',
#  'construction debris dump illegally near near the railway station obstruct road',
#  'construction debris dump illegally near near the railway station obstruct road',
#  'construction debris dump illegally near near the railway station obstruct road',
#  'construction debris dump illegally near near the temple obstruct road',
#  'construction debris dump illegally near near the temple obstruct road',
#  'construction debris dump illegally near near the temple obstruct road',
#  'construction debris dump illegally near near the temple obstruct road',
#  'construction debris dump illegally near near the temple obstruct road',
#  'construction debris dump illegally near near the temple obstruct road',
#  'construction debris dump illegally near next to the metro station obstruct road',
#  'construction debris dump illegally near next to the metro station obstruct road',
#  'construction debris dump illegally near next to the metro station obstruct road',
#  'construction debris dump illegally near next to the metro station obstruct road',
#  'construction debris dump illegally near next to the metro station obstruct road',
#  'construction debris dump illegally near on the main road obstruct road',
#  'construction debris dump illegally near on the main road obstruct road',
#  'construction debris dump illegally near on the main road obstruct road',
#  'construction debris dump illegally near on the main road obstruct road',
#  'construction debris dump illegally near on the main road obstruct road',
#  'construction debris dump illegally near on the main road obstruct road',
#  'construction debris dump illegally near on the main road obstruct road',
#  'construction debris dump illegally near opposite the hospital obstruct road',
#  'construction debris dump illegally near opposite the hospital obstruct road',
#  'construction debris dump illegally near opposite the hospital obstruct road',
#  'construction debris dump illegally near opposite the hospital obstruct road',
#  'construction debris dump on the roadside near at the bus stop obstructing traffic',
#  'construction debris dump on the roadside near beside the park obstruct traffic',
#  'construction debris dump on the roadside near beside the park obstruct traffic',
#  'construction debris dump on the roadside near by the lake obstruct traffic',
#  'construction debris dump on the roadside near in our colony obstruct traffic',
#  'construction debris dump on the roadside near in our colony obstruct traffic',
#  'construction debris dump on the roadside near in our colony obstruct traffic',
#  'construction debris dump on the roadside near inside the hostel obstruct traffic',
#  'construction debris dump on the roadside near near the market obstruct traffic',
#  'construction debris dump on the roadside near near the market obstruct traffic',
#  'construction debris dump on the roadside near near the market obstruct traffic',
#  'construction debris dump on the roadside near outside the school obstruct traffic',
#  'contaminated water come from municipal tap in at the bus stop hyderabad',
#  'contaminated water come from municipal tap in at the bus stop trichy',
#  'contaminated water come from municipal tap in at the bus stop visakhapatnam',
#  'contaminated water come from municipal tap in behind the apartment jaipur',
#  'contaminated water come from municipal tap in behind the apartment jaipur',
#  'contaminated water come from municipal tap in behind the apartment mumbai',
#  'contaminated water come from municipal tap in behind the apartment vellore',
#  'contaminated water come from municipal tap in beside the park nagpur',
#  'contaminated water come from municipal tap in beside the park pune',
#  'contaminated water come from municipal tap in beside the park surat',
#  'contaminated water come from municipal tap in by the lake bengaluru',
#  'contaminated water come from municipal tap in by the lake mumbai',
#  'contaminated water come from municipal tap in by the lake patna',
#  'contaminated water come from municipal tap in by the lake patna',
#  'contaminated water come from municipal tap in by the lake surat',
#  'contaminated water come from municipal tap in by the lake thiruvananthapuram',
#  'contaminated water come from municipal tap in by the lake visakhapatnam',
#  'contaminated water come from municipal tap in in our colony bengaluru',
#  'contaminated water come from municipal tap in in our colony chennai',
#  'contaminated water come from municipal tap in in our colony kolkata',
#  'contaminated water come from municipal tap in in our colony nagpur',
#  'contaminated water come from municipal tap in in our colony surat',
#  'contaminated water come from municipal tap in in our colony trichy',
# ...
#  'dairy product from local shop in patna have foul smell',
#  'dairy product from local shop in pune have foul smell',
#  'dairy product from mess in bengaluru have foul smell',
#  'dairy product from mess in chennai have foul smell',
#  'dairy product from mess in delhi have foul smell',
#  'dairy product from mess in jaipur have foul smell',
#  'dairy product from mess in jaipur have foul smell',
#  'dairy product from mess in lucknow have foul smell',
#  'dairy product from mess in madurai have foul smell',
#  'dairy product from mess in mangalore have foul smell',
#  'dairy product from mess in patna have foul smell',
#  'dairy product from mess in vellore have foul smell',
#  'dairy product from milkman in coimbatore have foul smell',
#  'dairy product from milkman in indore have foul smell',
#  'dairy product from milkman in madurai have foul smell',
#  'dairy product from milkman in mangalore have foul smell',
#  'dairy product from milkman in trichy have foul smell',
#  'dairy product from milkman in vellore have foul smell',
#  'dairy product from milkman in visakhapatnam have foul smell',
#  'dairy product from ration shop in bhopal have foul smell',
#  'dairy product from ration shop in chennai have foul smell',
#  'dairy product from ration shop in chennai have foul smell',
#  'dairy product from ration shop in coimbatore have foul smell',
#  'dairy product from ration shop in coimbatore have foul smell',
#  'dairy product from ration shop in guwahati have foul smell',
#  'dairy product from ration shop in jaipur have foul smell',
#  'dairy product from ration shop in mangalore have foul smell',
#  'dairy product from ration shop in mumbai have foul smell',
#  'dairy product from ration shop in nagpur have foul smell',
#  'dairy product from ration shop in patna have foul smell',
#  'dairy product from ration shop in pune have foul smell',
#  'dairy product from ration shop in pune have foul smell',
#  'dairy product from restaurant in indore have foul smell',
#  'dairy product from restaurant in kochi have foul smell',
#  'dairy product from restaurant in lucknow have foul smell',
#  'dairy product from restaurant in madurai have foul smell',
#  'dairy product from restaurant in mysuru have foul smell',
#  'dairy product from street vendor in hyderabad have foul smell',
#  'dairy product from street vendor in jaipur have foul smell',
#  'dairy product from street vendor in nagpur have foul smell',
#  'dairy product from street vendor in thiruvananthapuram have foul smell',
#  'dairy product from tea stall in bengaluru have foul smell',
#  'dairy product from tea stall in chennai have foul smell',
#  'dairy product from tea stall in guwahati have foul smell',
#  'dairy product from tea stall in jaipur have foul smell',
#  'dairy product from tea stall in kochi have foul smell',
#  'dairy product from tea stall in kolkata have foul smell',
#  'dairy product from tea stall in lucknow have foul smell',
#  'dairy product from tea stall in pune have foul smell',
#  'dairy product from tea stall in thiruvananthapuram have foul smell',
#  'dairy product from the bakery in bengaluru have a strange smell',
#  'dairy product from the bakery in lucknow have a strange smell',
#  'dairy product from the bakery in nagpur have a strange smell',
#  'dairy product from the bakery in pune have a strange smell',
#  'dairy product from the canteen in delhi have a strange smell',
#  'dairy product from the canteen in thiruvananthapuram have a strange smell',
#  'dairy product from the dhabha in guwahati have a strange smell',
#  'dairy product from the local shop in nagpur have a strange smell',
#  'dairy product from the mess in hyderabad have a strange smell',
#  'dairy product from the milkman in bengaluru have a strange smell',
#  'dairy product from the milkman in hyderabad have a strange smell',
#  'dairy product from the milkman in patna have a strange smell',
#  'dairy product from the milkman in vellore have a strange smell',
#  'dairy product from the ration shop in vellore have a strange smell',
#  'dairy product from the tea stall in bhopal have a strange smell',
#  'dairy product from the tea stall in bhopal have a strange smell',
#  'dairy product from the tea stall in pune have a strange smell',
#  'dairy product from vegetable stall in bengaluru have foul smell',
#  'dairy product from vegetable stall in vellore have foul smell',
#  'dengue case be rise because of mosquito everywhere',
#  'dirty water be come from the municipal tap in at the bus stop bengaluru',
#  'dirty water be come from the municipal tap in by the lake coimbatore',
#  'dirty water be come from the municipal tap in in our colony bhopal',
#  'dirty water be come from the municipal tap in in our colony delhi',
#  'dirty water be come from the municipal tap in in our colony madurai',
#  'dirty water be come from the municipal tap in in the municipal ward delhi',
#  'dirty water be come from the municipal tap in in the municipal ward guwahati',
#  'dirty water be come from the municipal tap in in the municipal ward jaipur',
#  'dirty water be come from the municipal tap in in the municipal ward kolkata',
#  'dirty water be come from the municipal tap in inside the hostel madurai',
#  'dirty water be come from the municipal tap in near the market hyderabad',
#  'dirty water be come from the municipal tap in near the market kolkata',
#  'dirty water be come from the municipal tap in near the market madurai',
#  'dirty water be come from the municipal tap in near the market nagpur',
#  'dirty water be come from the municipal tap in near the temple bengaluru',
#  'dirty water be come from the municipal tap in on the main road bengaluru',
#  'dirty water be come from the municipal tap in on the main road nagpur',
#  'dirty water be come from the municipal tap in on the main road patna',
#  'dirty water be come from the municipal tap in on the main road pune',
#  'dirty water be come from the municipal tap in outside the school chennai',
#  'dirty water be come through the pipeline in my street',
#  'doctor give wrong prescription cause health issue',
#  'drunk men be create nuisance near the bus stop daily',
#  'dump yard near the colony emit foul smell at night in bhopal',
#  'dump yard near the colony emit foul smell at night in chennai',
#  'dump yard near the colony emit foul smell at night in coimbatore',
#  'dump yard near the colony emit foul smell at night in delhi',
#  'dump yard near the colony emit foul smell at night in guwahati',
#  'dump yard near the colony emit foul smell at night in hyderabad',
#  'dump yard near the colony emit foul smell at night in jaipur',
#  'dump yard near the colony emit foul smell at night in jaipur',
#  'dump yard near the colony emit foul smell at night in kochi',
#  'dump yard near the colony emit foul smell at night in kolkata',
#  'dump yard near the colony emit foul smell at night in kolkata',
#  'dump yard near the colony emit foul smell at night in kolkata',
#  'dump yard near the colony emit foul smell at night in lucknow',
#  'dump yard near the colony emit foul smell at night in madurai',
#  'dump yard near the colony emit foul smell at night in madurai',
#  'dump yard near the colony emit foul smell at night in mumbai',
#  'dump yard near the colony emit foul smell at night in mumbai',
#  'dump yard near the colony emit foul smell at night in nagpur',
#  'dump yard near the colony emit foul smell at night in patna',
#  'dump yard near the colony emit foul smell at night in patna',
#  'dump yard near the colony emit foul smell at night in pune',
#  'dump yard near the colony emit foul smell at night in pune',
#  'dump yard smell be unbearable at night',
#  'dumpyard near at the bus stop release foul smell daily',
#  'dumpyard near at the bus stop release foul smell daily',
#  'dumpyard near at the bus stop release foul smell daily',
#  'dumpyard near at the bus stop release foul smell daily',
#  'dumpyard near behind the apartment release foul smell daily',
#  'dumpyard near behind the apartment release foul smell daily',
#  'dumpyard near behind the apartment release foul smell daily',
#  'dumpyard near beside the park release foul smell daily',
#  'dumpyard near beside the park release foul smell daily',
#  'dumpyard near beside the park release foul smell daily',
#  'dumpyard near beside the park release foul smell daily',
#  'dumpyard near by the lake release foul smell daily',
#  'dumpyard near by the lake release foul smell daily',
#  'dumpyard near by the lake release foul smell daily',
#  'dumpyard near by the lake release foul smell daily',
#  'dumpyard near by the lake release foul smell daily',
#  'dumpyard near in our colony release foul smell daily',
#  'dumpyard near in our colony release foul smell daily',
#  'dumpyard near in our colony release foul smell daily',
#  'dumpyard near in our colony release foul smell daily',
#  'dumpyard near in the municipal ward release foul smell daily',
#  'dumpyard near in the municipal ward release foul smell daily',
#  'dumpyard near in the municipal ward release foul smell daily',
#  'dumpyard near in the municipal ward release foul smell daily',
#  'dumpyard near in the municipal ward release foul smell daily',
#  'dumpyard near inside the hostel release foul smell daily',
#  'dumpyard near inside the hostel release foul smell daily',
#  'dumpyard near inside the hostel release foul smell daily',
#  'dumpyard near inside the hostel release foul smell daily',
#  'dumpyard near inside the hostel release foul smell daily',
#  'dumpyard near inside the hostel release foul smell daily',
#  'dumpyard near near the market release foul smell daily',
#  'dumpyard near near the market release foul smell daily',
#  'dumpyard near near the railway station release foul smell daily',
#  'dumpyard near near the railway station release foul smell daily',
#  'dumpyard near near the railway station release foul smell daily',
#  'dumpyard near near the railway station release foul smell daily',
#  'dumpyard near near the railway station release foul smell daily',
#  'dumpyard near near the railway station release foul smell daily',
#  'dumpyard near near the railway station release foul smell daily',
#  'dumpyard near near the temple release foul smell daily',
#  'dumpyard near near the temple release foul smell daily',
#  'dumpyard near near the temple release foul smell daily',
#  'dumpyard near near the temple release foul smell daily',
#  'dumpyard near near the temple release foul smell daily',
#  'dumpyard near next to the metro station release foul smell daily',
#  'dumpyard near next to the metro station release foul smell daily',
#  'dumpyard near next to the metro station release foul smell daily',
#  'dumpyard near next to the metro station release foul smell daily',
#  'dumpyard near on the main road release foul smell daily',
#  'dumpyard near on the main road release foul smell daily',
#  'dumpyard near on the main road release foul smell daily',
#  'dumpyard near on the main road release foul smell daily',
#  'dumpyard near opposite the hospital release foul smell daily',
#  'dumpyard near outside the school release foul smell daily',
#  'dumpyard near outside the school release foul smell daily',
#  'dumpyard near outside the school release foul smell daily',
#  'dumpyard near outside the school release foul smell daily',
#  'essential medicine unavailable at hospital pharmacy in bengaluru',
#  'essential medicine unavailable at hospital pharmacy in bengaluru',
#  'essential medicine unavailable at hospital pharmacy in bengaluru',
#  'essential medicine unavailable at hospital pharmacy in bengaluru',
#  'essential medicine unavailable at hospital pharmacy in bhopal',
#  'essential medicine unavailable at hospital pharmacy in bhopal',
#  'essential medicine unavailable at hospital pharmacy in bhopal',
#  'essential medicine unavailable at hospital pharmacy in chennai',
#  'essential medicine unavailable at hospital pharmacy in chennai',
#  'essential medicine unavailable at hospital pharmacy in chennai',
#  'essential medicine unavailable at hospital pharmacy in chennai',
#  'essential medicine unavailable at hospital pharmacy in chennai',
#  'essential medicine unavailable at hospital pharmacy in coimbatore',
#  'essential medicine unavailable at hospital pharmacy in coimbatore',
#  'essential medicine unavailable at hospital pharmacy in coimbatore',
#  'essential medicine unavailable at hospital pharmacy in coimbatore',
#  'essential medicine unavailable at hospital pharmacy in coimbatore',
#  'essential medicine unavailable at hospital pharmacy in delhi',
#  'essential medicine unavailable at hospital pharmacy in delhi',
#  'essential medicine unavailable at hospital pharmacy in guwahati',
#  'essential medicine unavailable at hospital pharmacy in guwahati',
#  'essential medicine unavailable at hospital pharmacy in guwahati',
#  'essential medicine unavailable at hospital pharmacy in hyderabad',
#  'essential medicine unavailable at hospital pharmacy in hyderabad',
#  'essential medicine unavailable at hospital pharmacy in hyderabad',
#  'essential medicine unavailable at hospital pharmacy in indore',
#  'essential medicine unavailable at hospital pharmacy in indore',
#  'essential medicine unavailable at hospital pharmacy in indore',
#  'essential medicine unavailable at hospital pharmacy in indore',
#  'essential medicine unavailable at hospital pharmacy in jaipur',
#  'essential medicine unavailable at hospital pharmacy in jaipur',
#  'essential medicine unavailable at hospital pharmacy in jaipur',
#  'essential medicine unavailable at hospital pharmacy in kochi',
#  'essential medicine unavailable at hospital pharmacy in kochi',
#  'essential medicine unavailable at hospital pharmacy in kolkata',
#  'essential medicine unavailable at hospital pharmacy in kolkata',
#  'essential medicine unavailable at hospital pharmacy in kolkata',
#  'essential medicine unavailable at hospital pharmacy in kolkata',
#  'essential medicine unavailable at hospital pharmacy in kolkata',
#  'essential medicine unavailable at hospital pharmacy in lucknow',
#  'essential medicine unavailable at hospital pharmacy in lucknow',
#  'essential medicine unavailable at hospital pharmacy in lucknow',
#  'essential medicine unavailable at hospital pharmacy in madurai',
#  'essential medicine unavailable at hospital pharmacy in madurai',
#  'essential medicine unavailable at hospital pharmacy in madurai',
#  'essential medicine unavailable at hospital pharmacy in mangalore',
#  'essential medicine unavailable at hospital pharmacy in mangalore',
#  'essential medicine unavailable at hospital pharmacy in mangalore',
#  'essential medicine unavailable at hospital pharmacy in mangalore',
#  'essential medicine unavailable at hospital pharmacy in mangalore',
#  'essential medicine unavailable at hospital pharmacy in mumbai',
#  'essential medicine unavailable at hospital pharmacy in mumbai',
#  'essential medicine unavailable at hospital pharmacy in mumbai',
#  'essential medicine unavailable at hospital pharmacy in mysuru',
#  'essential medicine unavailable at hospital pharmacy in mysuru',
#  'essential medicine unavailable at hospital pharmacy in mysuru',
#  'essential medicine unavailable at hospital pharmacy in mysuru',
#  'essential medicine unavailable at hospital pharmacy in nagpur',
#  'essential medicine unavailable at hospital pharmacy in nagpur',
#  'essential medicine unavailable at hospital pharmacy in nagpur',
#  'essential medicine unavailable at hospital pharmacy in nagpur',
#  'essential medicine unavailable at hospital pharmacy in patna',
#  'essential medicine unavailable at hospital pharmacy in patna',
#  'essential medicine unavailable at hospital pharmacy in pune',
#  'essential medicine unavailable at hospital pharmacy in pune',
#  'essential medicine unavailable at hospital pharmacy in surat',
#  'essential medicine unavailable at hospital pharmacy in surat',
#  'essential medicine unavailable at hospital pharmacy in thiruvananthapuram',
#  'essential medicine unavailable at hospital pharmacy in thiruvananthapuram',
#  'essential medicine unavailable at hospital pharmacy in thiruvananthapuram',
#  'essential medicine unavailable at hospital pharmacy in thiruvananthapuram',
#  'essential medicine unavailable at hospital pharmacy in thiruvananthapuram',
#  ...]

# %% [markdown]
# Vectorization / Embeddings (TF-IDF, Word2Vec, BERT)

# %% [markdown]
# vectorixation and stop word removing and negation handling are in each model training

# %% [markdown]
# Save dataset as emotion base & category base

# %%
(
    df[["complaint", "emotion"]]
        .sort_values(ascending=True, by="emotion", ignore_index=True)
        .to_csv("../data/cleaned/complaints_by_emotion.csv", index=False)
)

# %%
(
    df[["complaint", "category"]]
        .sort_values(ascending=True, by="category", ignore_index=True)
        .to_csv("../data/cleaned/complaints_by_category.csv", index=False)
)
