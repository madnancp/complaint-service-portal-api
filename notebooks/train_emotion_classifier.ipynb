# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/cleaned/complaints_by_emotion.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5075 entries, 0 to 5074
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   complaint  5075 non-null   object
#  1   emotion    5075 non-null   object
# dtypes: object(2)
# memory usage: 79.4+ KB

# %%
df.head()
# Out:
#                                            complaint emotion
# 0           Water tanker supplied muddy water today.   anger
# 1  Suspected dengue cases rising in near the temp...   anger
# 2  Suspected dengue cases rising in near the temp...   anger
# 3  Busy junction at near the market, Jaipur lacks...   anger
# 4  No water supply since morning in near the temp...   anger

# %%
plt.figure(figsize=(10, 2))
plt.bar(x=df["emotion"].value_counts().index, height=df["emotion"].value_counts().values)
plt.show()
